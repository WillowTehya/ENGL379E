# %%
def positive(sequence):
    counter = 0
    for i in sequence:
        if i > 0:
            counter += 1
    return counter

# %%
list = [-5, 3, 2, -2, 0]
positive(list)
# Out:
# 2

# %%
def pluses(sequence):
    sum = 0
    for i in sequence:
        if i > 0:
            sum += i
    return sum

# %%
list = [-5, 3, 2, -2, 0]
pluses(list)
# Out:
# 5

# %%
def doubleEven(sequence):
    result = []
    counter = 0.0
    for i in sequence:
        if counter%2.0 == 0.0:
            result += [i*2]
        else:
            result += [i]
        counter += 1    
    return result

# %%
list = [-5, 3, 2, -2, 0]
doubleModified(list)
# Out:
# [-10, 3, 4, -2, 0]

# %%
(for int i = 0; i < c; i++) {
    i += 1
}
for i in c:
# Out:
#   File "<ipython-input-24-76ec11bbb05f>", line 1
#     (for int i = 0; i < c; i++) {
#        ^
# SyntaxError: invalid syntax

# %%
def doubleString(x):
    result = []
    for i in x:
        if type(i) == str:
            result += [i*2]
        else:
            result += [i]
    return result

# %%
list = ['hi', 5, 7, 'bye']
doubleString(list)
# Out:
# ['hihi', 5, 7, 'byebye']
